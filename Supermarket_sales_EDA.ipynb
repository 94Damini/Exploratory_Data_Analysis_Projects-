# %% [markdown]
# <a href="https://colab.research.google.com/github/94Damini/Exploratory_Data_Analysis_Projects-/blob/main/Supermarket_sales_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![supermarket sale image.webp](data:image/webp;base64,...)

# %% [markdown]
# The growth of supermarkets in most populated cities are increasing and market competitions are also high. The dataset is one of the historical sales of supermarket company which has recorded in 3 different branches for 3 months data. Predictive data analytics methods are easy to apply with this dataset.
#
#
# # **Attribute information**
#
# Invoice id: Computer generated sales slip invoice identification number
#
# Branch: Branch of supercenter (3 branches are available identified by A, B and C).
#
# City: Location of supercenters
#
# Customer type: Type of customers, recorded by Members for customers using member card and Normal for without member card.
#
# Gender: Gender type of customer
#
# Product line: General item categorization groups - Electronic accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
#
# Unit price: Price of each product in $
#
# Quantity: Number of products purchased by customer
#
# Tax: 5% tax fee for customer buying
#
# Total: Total price including tax
#
# Date: Date of purchase (Record available from January 2019 to March 2019)
#
# Time: Purchase time (10am to 9pm)
#
# Payment: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)
#
# COGS: Cost of goods sold
#
# Gross margin percentage: Gross margin percentage
#
# Gross income: Gross income
#
# Rating: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %%
#*importing library*
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# importing Dataset and mounting drive
path = "supermarket_sales_sheet1.csv"
df1 = pd.read_csv('supermarket_sales_sheet1.csv', parse_dates = ['Date'])

# %% [markdown]
#  **1. Show first five rows from the Dataset**

# %%
df1.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# **2. Show last five rows from the Dataset**

# %%
df1.tail(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675 2019-01-29  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900 2019-03-02  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320 2019-02-09  13:22     Cash
# 998       65.82         1   3.2910    69.1110 2019-02-22  15:33     Cash
# 999       88.34         7  30.9190   649.2990 2019-02-18  13:28     Cash
#
# ...

# %% [markdown]
# **3. Display any random rows from Dataset**

# %%
df1.sample(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 795  605-83-1050      B   Mandalay        Normal    Male
# 610  421-95-9805      A     Yangon        Normal  Female
# 335  527-09-6272      A     Yangon        Member  Female
# 520  734-91-1155      B   Mandalay        Normal  Female
# 140  731-81-9469      C  Naypyitaw        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 795     Fashion accessories       27.18         2   2.7180   57.0780
# 610  Electronic accessories       28.96         1   1.4480   30.4080
# 335  Electronic accessories       28.45         5   7.1125  149.3625
# 520  Electronic accessories       45.71         3   6.8565  143.9865
# 140       Sports and travel       89.80        10  44.9000  942.9000
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 795 2019-03-15  16:26      Ewallet   54.36                 4.761905
# ...

# %% [markdown]
# **4. Find the shape of Dataset (no. of rows and columns)**

# %%
df1.shape
# Out:
# (1000, 17)

# %% [markdown]
# **5. Check for the no of null values in Dataset**

# %%
df1.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# **6. check for information like no of rows , no of columns , datatype of each column, memory requirement**

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %% [markdown]
# **7. Get overall statistics for dataset**

# %%
df1.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
# Divide the numerical column and categorial column into python list
cat = []
num = []
for column in df1.columns:
  if df1[column].nunique() > 10:
    num.append(column)
  else:
    cat.append(column)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %% [markdown]
# # **Univariate Analysis 📈**
#
# ---

# %% [markdown]
# **1. Find the most popular payment method used by customers
# (Categorial Column)?**

# %%
df1['Payment'].value_counts().plot(kind = 'bar')

# %% [markdown]
# **Observation:**
#
# most popular payment method used by customer is Ewallet followed by cash and credit card.

# %% [markdown]
# **2. which type of customers are largest in numbers ?**

# %%
df1['Customer type'].value_counts().plot(kind = 'pie', autopct= "%1.2f%%")

# %% [markdown]
#  **Observations:**
#
# Member type are more than normal customer type .

# %% [markdown]
# **3. which city has highest order rate ?**

# %%
sns.countplot(df1['City'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Observations**
#
# Yangon city has the highest order rate followed by Mandalay and Nayoyitaw city.

# %% [markdown]
# **4. find aggregate sales among branches(categorial column)?**

# %% [markdown]
#  Using Seaborn to make Bar plot
#
# ---

# %%
sns.countplot(df1['Branch'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
#  This is done by pandas library
#
# ---

# %%
df1['Branch'].value_counts().plot(kind = 'pie', autopct= "%1.2f%%")

# %%
df1['Branch'].value_counts().plot(kind = 'bar')

# %% [markdown]
# **Observations**
#
# 1. Brach A has the highest sale among three branches.
# 2. Branch A has 34% sale , B has 33.20% and C has 32.80% sales as shows in pie chart.

# %% [markdown]
# **5. what is the distribution of customer rating(numerical column)?**

# %%
sns.distplot(df1['Rating'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# From the above graph we can see that graph is normally distributed so skewness is very negligible.
df1['Rating'].skew()
# Out:
# 0.00900964876573073

# %% [markdown]
# **Observations:**
#
# Customer Rating is Normally Distributed as shown in graph  as there is 0.00900 skewness there so it is negligible skew in nature.
#
# Rating is densed in between 6 to 9 around near 7 .

# %% [markdown]
# **6. Find the Distribution of cost of goods sold (numerical column)?**

# %%
sns.distplot(df1['cogs'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df1['cogs'].skew()
# Out:
# 0.8925698049581418

# %%
# we can also plot boxplot for numerical columns
sns.boxplot(df1['cogs'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Observations:**
#
# cost of goods is positively skewed as shown in graph it has value of .8925

# %% [markdown]
# # **Bivariate Analysis / Multivariate Analysis 📉**
#
# ---

# %% [markdown]
# **7. Does the cost of goods sold affect the rating that the customers provide (numeric - numeric)?**

# %%
sns.scatterplot(df1['cogs'], df1['Rating'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Observations:**
# There is no relation found between cost of goods and rating given by customers.

# %% [markdown]
# **8. Does the gross income affect the ratings that the customer provide (numerical numerical) ?**

# %%
sns.scatterplot(df1['gross income'], df1['Rating'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Observation:**
# There is also no relation between Gross income and Customer rating.

# %% [markdown]
# **9.Find the most profitable Branch as per Gross income?**

# %%
sns.barplot(df1['Branch'], df1['gross income'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# find the most profitable Branch as per Gross income based on city? 
sns.barplot(df1['Branch'], df1['gross income'], hue= df1['City'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Observations:**
#
# 1. Most profitable Branch is B as per gross income from first bivariate graph.
# 2. Most profitable Branch is C  which is in Naypyitaw city as per gross income from second multivariate graph analysis.

# %% [markdown]
# **10. is there any relationship between gender and gross income (categorial-numerical )?**

# %%
sns.barplot(df1['Gender'], df1['gross income'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# we can also make boxplot for given question
sns.boxplot(df1['Gender'], df1['gross income'], hue=df1['Customer type'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Observation:**
#
# 1. Female has more gross income than male .
# 2. Female and male member has more gross income than female and male normal income  and overall female member income is highest among others.

# %% [markdown]
# **11. Find the product line that generate the most income?**

# %%
sns.barplot(df1['Product line'], df1['gross income'])
plt.xticks(rotation=80)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Observations:**
#
# Home and lifestyle product line has the highest income .

# %% [markdown]
# **12. Find the highest unit price in product line ? (numerical categorial)**

# %%
sns.barplot(df1['Product line'], df1['Unit price'])
plt.xticks(rotation=80)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Observations:**
#
# Fashion accesories has the highest unit price.

# %% [markdown]
# **13. Find different payment method used by customer citywise?**

# %%
sns.heatmap(pd.crosstab(df1['City'],df1['Payment']))

# %%
pd.crosstab(df1['City'],df1['Payment'])
# Out:
# Payment    Cash  Credit card  Ewallet
# City
# Mandalay    110          109      113
# Naypyitaw   124           98      106
# Yangon      110          104      126

# %% [markdown]
# **Observations:**
#
# ### City            Payment method
#
#
# Mandalay	  	   Ewallet
#
# Naypyitaw	       Cash
#
# Yangon           Ewallet

# %% [markdown]
# **14. Which product line is purchased in highest quantity?**

# %%
(df1.groupby('Product line').sum()['Quantity']).plot(kind='bar')

# %% [markdown]
# **Observations:**
# Electronic accessories is purchased in highest quantity.

# %% [markdown]
# **15. Display daily sales by day of week?**

# %%
dw_mapping = {
    0:'Mon',
    1:'Tues', 
    2:'Wed',
    3:'Thurs',
    4:'Fri',
    5:'Sat',
    6:'Sun'
    }

# %%
df1['day_of_week'] =df1['Date'].dt.dayofweek.map(dw_mapping)
df1.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df1['day_of_week'].value_counts().plot(kind='bar')

# %% [markdown]
# **Observations:**
#
# Saturday is  the day of highest sale followed by Tuesday.

# %% [markdown]
# **16. What will be the highest month for sales ?**

# %%
d_mapping = {
    1:'jan',
    2:'feb',
    3:'march',
    4:'april'
    }

# %%
df1['month']=df1['month'] =df1['Date'].dt.month.map(d_mapping)
df1.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df1['month'].value_counts().plot(kind='bar')

# %% [markdown]
# **observations:**
#
# Jan has the highest month of sales.
